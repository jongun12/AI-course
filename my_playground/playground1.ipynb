# %%
import cv2
from PIL import Image
import numpy as np

import matplotlib.pyplot as plt

# %%
path = '/home/kim/rokey/ragular_cours/AI-course/my_playground/make_docu/new_docu.jpg'
img = cv2.imread(path)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img_pil = Image.open(path).convert("RGB") # convert를 붙이지 않으면 원본 포멧에 맞게 열게 되는데, png의 경우 원본 이미지가 투명도 채널(4채널)을 가지는 경우가 있기 때문에 
# convert를 붙이는 게 안전하고 일반적이다.

# %%
type(img_pil)
# Out:
# PIL.Image.Image

# %%
arr_img = np.array(img_pil)

# %%
arr_img.shape
# Out:
# (1414, 1000, 3)

# %%
img.shape
# Out:
# (1414, 1000, 3)

# %%
rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
((arr_img == rgb_img)-1).sum()
# Out:
# np.int64(0)

# %%
arr_img.max()
# Out:
# np.uint8(255)

# %%
img.ravel().shape
img.ravel()[:10]
# Out:
# array([255, 255, 255, 254, 254, 254, 255, 255, 255, 254], dtype=uint8)

# %%
plt.hist(img.ravel(),256)
# Out:
# (array([9.386100e+04, 2.350800e+04, 1.509900e+04, 7.362000e+03,
#         2.964000e+03, 1.035000e+03, 2.310000e+02, 5.400000e+01,
#         3.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
# ...
